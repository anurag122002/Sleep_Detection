# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(rescale=1./255,
                                    validation_split=0.3
                                   )

# %%
classes = ["sleeping", "not sleeping"]

train = data_generator.flow_from_directory(
r"C:\Users\kinwa\Documents\Sleep_Detection",
target_size = (128,128),
classes=classes,
batch_size=20,
class_mode='categorical',
subset="training"
)

val = data_generator.flow_from_directory(
r"C:\Users\kinwa\Documents\Sleep_Detection",
target_size = (128,128),
classes=classes,
batch_size=20,
class_mode='categorical',
subset="validation"
)
# Out:
# Found 58 images belonging to 2 classes.
# Found 24 images belonging to 2 classes.

# %%
x_train, y_train = next(train)
x_val, y_val = next(val)

print(x_train[0].shape)
plt.imshow(x_train[0])
plt.show()
# Out:
# (128, 128, 3)

# %%
tf.keras.backend.clear_session()

model = Sequential([
    Conv2D(64, 7, activation="relu", padding="same",
                       input_shape=(128,128,3)),
    MaxPool2D(2),
    Conv2D(128, 5, activation="relu", padding="same"),
    #Conv2D(128, 3, activation="relu", padding="same"),
    MaxPool2D(2),
    #Conv2D(256, 3, activation="relu", padding="same"),
    Conv2D(128, 3, activation="relu", padding="same"),
    MaxPool2D(2),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dense(2, activation="softmax")
])
model.layers[0].trainable = False

model.compile(
    loss="categorical_crossentropy", 
    optimizer=Adam(learning_rate=1e-5), 
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 64)        │           9,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       4,194,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,564,802 (17.41 MB)
#  Trainable params: 4,555,330 (17.38 MB)
#  Non-trainable params: 9,472 (37.00 KB)

# %%
checkpoint = ModelCheckpoint("model1.weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
lr_callbacks = [checkpoint]

# %%
epochs=30
hist = model.fit(train,
                 epochs=epochs,
                 callbacks=lr_callbacks,
                 validation_data=val,)
# Out:
# Epoch 1/30
# C:\Users\kinwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.5643 - loss: 0.6891
# Epoch 1: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 873ms/step - accuracy: 0.5482 - loss: 0.6903 - val_accuracy: 0.5000 - val_loss: 0.6954
# Epoch 2/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.5302 - loss: 0.6961
# Epoch 2: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 701ms/step - accuracy: 0.5140 - loss: 0.6978 - val_accuracy: 0.5000 - val_loss: 0.6949
# Epoch 3/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.6422 - loss: 0.6779
# Epoch 3: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 705ms/step - accuracy: 0.6196 - loss: 0.6802 - val_accuracy: 0.5000 - val_loss: 0.6942
# Epoch 4/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.5308 - loss: 0.6923
# Epoch 4: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 796ms/step - accuracy: 0.5403 - loss: 0.6915 - val_accuracy: 0.5000 - val_loss: 0.6934
# Epoch 5/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.4154 - loss: 0.7066
# Epoch 5: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 764ms/step - accuracy: 0.4279 - loss: 0.7054 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 6/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.4658 - loss: 0.6902
# Epoch 6: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 737ms/step - accuracy: 0.4743 - loss: 0.6900 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 7/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.5944 - loss: 0.6803
# Epoch 7: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 727ms/step - accuracy: 0.5838 - loss: 0.6812 - val_accuracy: 0.5417 - val_loss: 0.6914
# Epoch 8/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.5845 - loss: 0.6832
# Epoch 8: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 728ms/step - accuracy: 0.5892 - loss: 0.6827 - val_accuracy: 0.5417 - val_loss: 0.6906
# Epoch 9/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.5151 - loss: 0.6932
# Epoch 9: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 754ms/step - accuracy: 0.5286 - loss: 0.6918 - val_accuracy: 0.5417 - val_loss: 0.6905
# Epoch 10/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.4974 - loss: 0.6839
# Epoch 10: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 847ms/step - accuracy: 0.5024 - loss: 0.6838 - val_accuracy: 0.5000 - val_loss: 0.6906
# Epoch 11/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - accuracy: 0.5260 - loss: 0.6941
# Epoch 11: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 861ms/step - accuracy: 0.5324 - loss: 0.6940 - val_accuracy: 0.5417 - val_loss: 0.6903
# Epoch 12/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.5602 - loss: 0.6858
# Epoch 12: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 852ms/step - accuracy: 0.5581 - loss: 0.6863 - val_accuracy: 0.5417 - val_loss: 0.6897
# Epoch 13/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - accuracy: 0.5354 - loss: 0.6764
# Epoch 13: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 864ms/step - accuracy: 0.5524 - loss: 0.6763 - val_accuracy: 0.5833 - val_loss: 0.6890
# Epoch 14/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.5533 - loss: 0.6726
# Epoch 14: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 920ms/step - accuracy: 0.5529 - loss: 0.6734 - val_accuracy: 0.5417 - val_loss: 0.6886
# Epoch 15/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.6601 - loss: 0.6824
# Epoch 15: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 873ms/step - accuracy: 0.6588 - loss: 0.6818 - val_accuracy: 0.6250 - val_loss: 0.6882
# Epoch 16/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.6952 - loss: 0.6719
# Epoch 16: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 832ms/step - accuracy: 0.6895 - loss: 0.6724 - val_accuracy: 0.5417 - val_loss: 0.6877
# Epoch 17/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 630ms/step - accuracy: 0.5687 - loss: 0.6833
# Epoch 17: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 874ms/step - accuracy: 0.5774 - loss: 0.6819 - val_accuracy: 0.5833 - val_loss: 0.6873
# Epoch 18/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.5884 - loss: 0.6728
# Epoch 18: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 849ms/step - accuracy: 0.5878 - loss: 0.6738 - val_accuracy: 0.6667 - val_loss: 0.6867
# Epoch 19/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.5260 - loss: 0.6650
# Epoch 19: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 873ms/step - accuracy: 0.5324 - loss: 0.6666 - val_accuracy: 0.5833 - val_loss: 0.6859
# Epoch 20/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.6008 - loss: 0.6768
# Epoch 20: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 832ms/step - accuracy: 0.6057 - loss: 0.6767 - val_accuracy: 0.5833 - val_loss: 0.6857
# Epoch 21/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 0.5823 - loss: 0.6787
# Epoch 21: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 869ms/step - accuracy: 0.5833 - loss: 0.6770 - val_accuracy: 0.5417 - val_loss: 0.6852
# Epoch 22/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.6882 - loss: 0.6648
# Epoch 22: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 824ms/step - accuracy: 0.6886 - loss: 0.6648 - val_accuracy: 0.5417 - val_loss: 0.6846
# Epoch 23/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.5487 - loss: 0.6764
# Epoch 23: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 840ms/step - accuracy: 0.5409 - loss: 0.6785 - val_accuracy: 0.5000 - val_loss: 0.6840
# Epoch 24/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.6201 - loss: 0.6733
# Epoch 24: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 846ms/step - accuracy: 0.6289 - loss: 0.6724 - val_accuracy: 0.5833 - val_loss: 0.6830
# Epoch 25/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.5366 - loss: 0.6803
# Epoch 25: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 867ms/step - accuracy: 0.5490 - loss: 0.6799 - val_accuracy: 0.5833 - val_loss: 0.6825
# Epoch 26/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.6096 - loss: 0.6498
# Epoch 26: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 873ms/step - accuracy: 0.6038 - loss: 0.6524 - val_accuracy: 0.5833 - val_loss: 0.6817
# Epoch 27/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.6658 - loss: 0.6483
# Epoch 27: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 868ms/step - accuracy: 0.6675 - loss: 0.6476 - val_accuracy: 0.5833 - val_loss: 0.6809
# Epoch 28/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.7608 - loss: 0.6541
# Epoch 28: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 869ms/step - accuracy: 0.7559 - loss: 0.6541 - val_accuracy: 0.7083 - val_loss: 0.6795
# Epoch 29/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.6580 - loss: 0.6637
# Epoch 29: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 857ms/step - accuracy: 0.6659 - loss: 0.6615 - val_accuracy: 0.7083 - val_loss: 0.6783
# Epoch 30/30
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.5868 - loss: 0.6817
# Epoch 30: saving model to model1.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 868ms/step - accuracy: 0.6039 - loss: 0.6783 - val_accuracy: 0.7083 - val_loss: 0.6781

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_json = model.to_json()
with open("model_a1.json","w") as json_file:
    json_file.write(model_json)
